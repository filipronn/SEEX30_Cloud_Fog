# %%
import openeo
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20,10]

# %%
from OpenEOconfig import user, passwd,eo_service_url
from OpenEOdemo_helpers import show_result

# %%
connection=openeo.connect(eo_service_url)
print(eo_service_url)
print(user)
connection.authenticate_basic(username=user,password=passwd)
# Out:
# https://openeo.digitalearth.se
# ix101
# ---------------------------------------------------------------------------
# OpenEoApiError                            Traceback (most recent call last)
# Cell In[8], line 4
#       2 print(eo_service_url)
#       3 print(user)
# ----> 4 connection.authenticate_basic(username=user,password=passwd)
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:357, in Connection.authenticate_basic(self, username, password)
#     354     if username is None:
#     355         raise OpenEoClientException("No username/password given or found.")
# --> 357 resp = self.get(
#     358     '/credentials/basic',
#     359     # /credentials/basic is the only endpoint that expects a Basic HTTP auth
#     360     auth=HTTPBasicAuth(username, password)
#     361 ).json()
#     362 # Switch to bearer based authentication in further requests.
#     363 self.auth = BasicBearerAuth(access_token=resp["access_token"])
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:220, in RestApiConnection.get(self, path, stream, auth, **kwargs)
#     211 def get(self, path: str, stream: bool = False, auth: Optional[AuthBase] = None, **kwargs) -> Response:
#     212     """
#     213     Do GET request to REST API.
#     214
#    (...)
#     218     :return: response: Response
#     219     """
# --> 220     return self.request("get", path=path, stream=stream, auth=auth, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:769, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     762     return super(Connection, self).request(
#     763         method=method, path=path, headers=headers, auth=auth,
#     764         check_error=check_error, expected_status=expected_status, **kwargs,
#     765     )
#     767 try:
#     768     # Initial request attempt
# --> 769     return _request()
#     770 except OpenEoApiError as api_exc:
#     771     if api_exc.http_status_code in {401, 403} and api_exc.code == "TokenInvalid":
#     772         # Auth token expired: can we refresh?
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:762, in Connection.request.<locals>._request()
#     761 def _request():
# --> 762     return super(Connection, self).request(
#     763         method=method, path=path, headers=headers, auth=auth,
#     764         check_error=check_error, expected_status=expected_status, **kwargs,
#     765     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:168, in RestApiConnection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     166 expected_status = ensure_list(expected_status) if expected_status else []
#     167 if check_error and status >= 400 and status not in expected_status:
# --> 168     self._raise_api_error(resp)
#     169 if expected_status and status not in expected_status:
#     170     raise OpenEoRestError("Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     171         m=method.upper(), p=path, s=status, e=expected_status, body=resp.text)
#     172     )
#
# File ~/.local/lib/python3.10/site-packages/openeo/rest/connection.py:188, in RestApiConnection._raise_api_error(self, response)
#     186     error_message = info.get("message")
#     187     if error_code and isinstance(error_code, str) and error_message and isinstance(error_message, str):
# --> 188         raise OpenEoApiError(
#     189             http_status_code=status_code,
#     190             code=error_code,
#     191             message=error_message,
#     192             id=info.get("id"),
#     193             url=info.get("url"),
#     194         )
#     196 # Failed to parse it as a compliant openEO API error: show body as-is in the exception.
#     197 text = response.text
#
# OpenEoApiError: [403] CredentialsInvalid: Credentials are not correct.

# %%
connection.list_collections()
# Out:
# [{'stac_version': '1.0.0',
#   'type': 'Collection',
#   'id': 'NMD_Produktivitet_v1_1',
#   'title': 'NMD_Produktivitet_v1_1',
#   'description': 'Tilläggsskikt produktivitet',
#   'license': 'CC0-1.0',
#   'extent': {'spatial': {'bbox': [[8.000013270356117,
#       54.99999600913266,
#       25.000000809024733,
#       68.99999769658118]]},
#    'temporal': {'interval': [['2023-04-27T06:26:59.086425Z',
#       '2023-04-27T06:26:59.086425Z']]}},
#   'links': [{'rel': 'root',
#     'href': 'https://explorer.digitalearth.se/stac',
#     'type': 'application/json',
#     'title': 'Default ODC Explorer instance'},
#    {'rel': 'self',
#     'href': 'https://explorer.digitalearth.se/stac/collections/NMD_Produktivitet_v1_1'},
#    {'rel': 'items',
#     'href': 'https://explorer.digitalearth.se/stac/collections/NMD_Produktivitet_v1_1/items'},
#    {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#     'href': 'https://explorer.digitalearth.se/stac/collections/NMD_Produktivitet_v1_1/queryables'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/NMD_Produktivitet_v1_1/2023-4'}],
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [8.000013270356117, 25.000000809024733],
#     'reference_system': 4326},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [54.99999600913266, 68.99999769658118],
#     'reference_system': 4326},
#    't': {'type': 'temporal',
#     'extent': ['2023-04-27T06:26:59.086425Z', '2023-04-27T06:26:59.086425Z'],
#     'step': None},
#    'bands': {'type': 'bands', 'values': ['produktivitet']}},
#   'summaries': {}},
#  {'stac_version': '1.0.0',
#   'type': 'Collection',
#   'id': 'nmd2018bas_ogeneraliserad_v1_1',
#   'title': 'nmd2018bas_ogeneraliserad_v1_1',
#   'description': 'Nationella marktäckedata (NMD)',
#   'license': 'CC0-1.0',
#   'extent': {'spatial': {'bbox': [[8.000013270356117,
#       54.99999600913266,
#       25.000000809024733,
#       68.99999769658118]]},
#    'temporal': {'interval': [['2023-04-25T14:23:34.643233Z',
#       '2023-04-25T14:23:34.643233Z']]}},
#   'links': [{'rel': 'root',
#     'href': 'https://explorer.digitalearth.se/stac',
#     'type': 'application/json',
#     'title': 'Default ODC Explorer instance'},
#    {'rel': 'self',
#     'href': 'https://explorer.digitalearth.se/stac/collections/nmd2018bas_ogeneraliserad_v1_1'},
#    {'rel': 'items',
#     'href': 'https://explorer.digitalearth.se/stac/collections/nmd2018bas_ogeneraliserad_v1_1/items'},
#    {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#     'href': 'https://explorer.digitalearth.se/stac/collections/nmd2018bas_ogeneraliserad_v1_1/queryables'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/nmd2018bas_ogeneraliserad_v1_1/2023-4'}],
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [8.000013270356117, 25.000000809024733],
#     'reference_system': 4326},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [54.99999600913266, 68.99999769658118],
#     'reference_system': 4326},
#    't': {'type': 'temporal',
#     'extent': ['2023-04-25T14:23:34.643233Z', '2023-04-25T14:23:34.643233Z'],
#     'step': None},
#    'bands': {'type': 'bands', 'values': ['basskikt']}},
#   'summaries': {}},
#  {'stac_version': '1.0.0',
#   'type': 'Collection',
#   'id': 's2_msi_l1c',
#   'title': 's2_msi_l1c',
#   'description': 'Sentinel-2 Level1C - Ortho Rectified Top of Atmosphere Reflectance',
#   'license': 'CC-BY-4.0',
#   'extent': {'spatial': {'bbox': [[8.999626281785673,
#       54.9150072246983,
#       26.330890180835535,
#       69.4096405079696]]},
#    'temporal': {'interval': [['2015-07-04T10:10:06.027000Z',
#       '2023-11-06T10:51:39.024000Z']]}},
#   'links': [{'rel': 'root',
#     'href': 'https://explorer.digitalearth.se/stac',
#     'type': 'application/json',
#     'title': 'Default ODC Explorer instance'},
#    {'rel': 'self',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l1c'},
#    {'rel': 'items',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l1c/items'},
#    {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l1c/queryables'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2015-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2016-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2017-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2018-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2019-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2020-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2021-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2022-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l1c/2023-11'}],
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [8.999626281785673, 26.330890180835535],
#     'reference_system': 4326},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [54.9150072246983, 69.4096405079696],
#     'reference_system': 4326},
#    't': {'type': 'temporal',
#     'extent': ['2015-07-04T10:10:06.027000Z', '2023-11-06T10:51:39.024000Z'],
#     'step': None},
#    'bands': {'type': 'bands',
#     'values': ['b01',
#      'b02',
#      'b03',
#      'b04',
#      'b05',
#      'b06',
#      'b07',
#      'b08',
#      'b09',
#      'b10',
#      'b11',
#      'b12',
#      'b8a']}},
#   'summaries': {'eo:cloud_cover': {'minimum': 0, 'maximum': 100},
#    'odc:region_code': ['e.g. 33VUE'],
#    'sat:orbit_state': ['ascending', 'descending'],
#    'sat:relative_orbit': {'minimum': 0, 'maximum': 100},
#    'view:incidence_angle': {'minimum': 0, 'maximum': 360}}},
#  {'stac_version': '1.0.0',
#   'type': 'Collection',
#   'id': 's2_msi_l2a',
#   'title': 's2_msi_l2a',
#   'description': 'Sentinel-2 MSI L2A Cloud-Optimized GeoTIFFs',
#   'license': 'CC-BY-4.0',
#   'extent': {'spatial': {'bbox': [[-180.0,
#       53.071256525792954,
#       179.52092178474308,
#       72.09958113028067]]},
#    'temporal': {'interval': [['2018-03-01T10:30:19.027000Z',
#       '2023-11-06T10:51:39.024000Z']]}},
#   'links': [{'rel': 'root',
#     'href': 'https://explorer.digitalearth.se/stac',
#     'type': 'application/json',
#     'title': 'Default ODC Explorer instance'},
#    {'rel': 'self',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l2a'},
#    {'rel': 'items',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l2a/items'},
#    {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s2_msi_l2a/queryables'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2018-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2019-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2020-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2021-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2022-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s2_msi_l2a/2023-11'}],
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [-180.0, 179.52092178474308],
#     'reference_system': 4326},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [53.071256525792954, 72.09958113028067],
#     'reference_system': 4326},
#    't': {'type': 'temporal',
#     'extent': ['2018-03-01T10:30:19.027000Z', '2023-11-06T10:51:39.024000Z'],
#     'step': None},
#    'bands': {'type': 'bands',
#     'values': ['aot',
#      'b01',
#      'b02',
#      'b03',
#      'b04',
#      'b05',
#      'b06',
#      'b07',
#      'b08',
#      'b09',
#      'b11',
#      'b12',
#      'b8a',
#      'cld',
#      'scl',
#      'snw',
#      'wvp']}},
#   'summaries': {'eo:cloud_cover': {'minimum': 0, 'maximum': 100},
#    'odc:region_code': ['e.g. 33VUE'],
#    'sat:orbit_state': ['ascending', 'descending'],
#    'sat:relative_orbit': {'minimum': 0, 'maximum': 100}}},
#  {'stac_version': '1.0.0',
#   'type': 'Collection',
#   'id': 's3_olci_l2wfr',
#   'title': 's3_olci_l2wfr',
#   'description': 'Sentinel-3 OLCI L2WFR Cloud-Optimized GeoTIFFs',
#   'license': 'CC-BY-4.0',
#   'extent': {'spatial': {'bbox': [[-35.82659999999999,
#       49.87969999686885,
#       74.83289999999998,
#       85.78769999979149]]},
#    'temporal': {'interval': [['2021-01-01T08:38:05.760064Z',
#       '2023-12-13T08:41:45.842098Z']]}},
#   'links': [{'rel': 'root',
#     'href': 'https://explorer.digitalearth.se/stac',
#     'type': 'application/json',
#     'title': 'Default ODC Explorer instance'},
#    {'rel': 'self',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s3_olci_l2wfr'},
#    {'rel': 'items',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s3_olci_l2wfr/items'},
#    {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#     'href': 'https://explorer.digitalearth.se/stac/collections/s3_olci_l2wfr/queryables'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2021-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2022-12'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-1'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-2'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-3'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-4'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-5'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-6'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-7'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-8'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-9'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-10'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-11'},
#    {'rel': 'child',
#     'href': 'https://explorer.digitalearth.se/stac/catalogs/s3_olci_l2wfr/2023-12'}],
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [-35.82659999999999, 74.83289999999998],
#     'reference_system': 4326},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [49.87969999686885, 85.78769999979149],
#     'reference_system': 4326},
#    't': {'type': 'temporal',
#     'extent': ['2021-01-01T08:38:05.760064Z', '2023-12-13T08:41:45.842098Z'],
#     'step': None},
#    'bands': {'type': 'bands',
#     'values': ['iwv',
#      'par',
#      'a865',
#      'oa01',
#      'oa02',
#      'oa03',
#      'oa04',
#      'oa05',
#      'oa06',
#      'oa07',
#      'oa08',
#      'oa09',
#      'oa10',
#      'oa11',
#      'oa12',
#      'oa16',
#      'oa17',
#      'oa18',
#      'oa21',
#      't865',
#      'chl_nn',
#      'tsm_nn',
#      'iwv_err',
#      'par_err',
#      'a865_err',
#      'oa01_err',
#      'oa02_err',
#      'oa03_err',
#      'oa04_err',
#      'oa05_err',
#      'oa06_err',
#      'oa07_err',
#      'oa08_err',
#      'oa09_err',
#      'oa10_err',
#      'oa11_err',
#      'oa12_err',
#      'oa16_err',
#      'oa17_err',
#      'oa18_err',
#      'oa21_err',
#      't865_err',
#      'wqsf_lsb',
#      'wqsf_msb',
#      'adg443_nn',
#      'chl_oc4me',
#      'kd490_m07',
#      'chl_nn_err',
#      'tsm_nn_err',
#      'adg443_nn_err',
#      'chl_oc4me_err',
#      'kd490_m07_err']}},
#   'summaries': {'eo:cloud_cover': {'minimum': 0, 'maximum': 100},
#    'sat:orbit_state': ['ascending', 'descending'],
#    'sat:absolute_orbit': ['e.g. 23636'],
#    'sat:relative_orbit': {'minimum': 0, 'maximum': 100}}}]
